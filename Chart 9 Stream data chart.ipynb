# %%
# Dependencies
# %matplotlib notebook
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import style
import time
style.use('ggplot')

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
target_user = "BBC"

compound_list = []
tweet_times = []
tweet_time_objects = []
time_in_between = []
counter=0

public_tweets = api.search(target_user, count=100, result_type="recent")
        
for tweet in public_tweets["statuses"]:
        
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    compound_list.append(compound)
        
    tweet_times.append(tweet["created_at"])
        
    counter += 1
    if counter % 20 == 0:
        print(tweet["created_at"])
         
sentiment = {"User": target_user,"Compound": np.mean(compound_list),"Tweet Count": len(compound_list)}
BBC_compound=np.mean(compound_list)
    
for x in range(len(tweet_times)):
    tweet_datetime = datetime.strptime(tweet_times[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects.append(tweet_datetime)
    if x % 20 == 0:
        print(tweet_times[x])
        print(tweet_datetime)
            
for x in range(len(tweet_time_objects)-1):
    hrs_apart = ((tweet_time_objects[x] - tweet_time_objects[x+1]).seconds) / 3600
    time_in_between.append(hrs_apart)

plt.scatter(range(len(time_in_between)+1), compound_list, marker="o",linewidth=0.25, alpha=0.8, color="r",edgecolor='k')
plt.xlim([0, len(time_in_between)])
plt.ylabel("Sentiment")
plt.xlabel("Tweets Ago")
plt.title("Tweet Sentiment Analysis")
# Out:
# Wed Sep 26 20:04:24 +0000 2018
# Wed Sep 26 20:04:16 +0000 2018
# Wed Sep 26 20:04:08 +0000 2018
# Wed Sep 26 20:04:01 +0000 2018
# Wed Sep 26 20:03:54 +0000 2018
# Wed Sep 26 20:04:28 +0000 2018
# 2018-09-26 20:04:28+00:00
# Wed Sep 26 20:04:24 +0000 2018
# 2018-09-26 20:04:24+00:00
# Wed Sep 26 20:04:16 +0000 2018
# 2018-09-26 20:04:16+00:00
# Wed Sep 26 20:04:08 +0000 2018
# 2018-09-26 20:04:08+00:00
# Wed Sep 26 20:04:00 +0000 2018
# 2018-09-26 20:04:00+00:00
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Tweet Sentiment Analysis')

# %%
# Target User
target_user = "New York Times"

compound_list = []
tweet_times = []
tweet_time_objects = []
time_in_between = []
counter=0

public_tweets = api.search(target_user, count=100, result_type="recent")
        
for tweet in public_tweets["statuses"]:
        
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    compound_list.append(compound)
        
    tweet_times.append(tweet["created_at"])
        
    counter += 1
    if counter % 20 == 0:
        print(tweet["created_at"])
         
sentiment = {"User": target_user,"Compound": np.mean(compound_list),"Tweet Count": len(compound_list)}
NYT_compound=np.mean(compound_list)

for x in range(len(tweet_times)):
    tweet_datetime = datetime.strptime(tweet_times[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects.append(tweet_datetime)
    if x % 20 == 0:
        print(tweet_times[x])
        print(tweet_datetime)
            
for x in range(len(tweet_time_objects)-1):
    hrs_apart = ((tweet_time_objects[x] - tweet_time_objects[x+1]).seconds) / 3600
    time_in_between.append(hrs_apart)

plt.scatter(range(len(time_in_between)+1), compound_list, marker="o",linewidth=0.25, alpha=0.8, color="b",edgecolor='k')
plt.xlim([0, len(time_in_between)])
plt.ylabel("Sentiment")
plt.xlabel("Tweets Ago")
plt.title("Tweet Sentiment Analysis")
# Out:
# Wed Sep 26 20:04:03 +0000 2018
# Wed Sep 26 20:03:31 +0000 2018
# Wed Sep 26 20:03:10 +0000 2018
# Wed Sep 26 20:02:43 +0000 2018
# Wed Sep 26 20:02:13 +0000 2018
# Wed Sep 26 20:04:29 +0000 2018
# 2018-09-26 20:04:29+00:00
# Wed Sep 26 20:04:03 +0000 2018
# 2018-09-26 20:04:03+00:00
# Wed Sep 26 20:03:31 +0000 2018
# 2018-09-26 20:03:31+00:00
# Wed Sep 26 20:03:07 +0000 2018
# 2018-09-26 20:03:07+00:00
# Wed Sep 26 20:02:43 +0000 2018
# 2018-09-26 20:02:43+00:00
# Text(0.5,1,'Tweet Sentiment Analysis')

# %%
# Target User
target_user = "CNN"

compound_list = []
tweet_times = []
tweet_time_objects = []
time_in_between = []
counter=0

public_tweets = api.search(target_user, count=100, result_type="recent")
        
for tweet in public_tweets["statuses"]:
        
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    compound_list.append(compound)
        
    tweet_times.append(tweet["created_at"])
        
    counter += 1
    if counter % 20 == 0:
        print(tweet["created_at"])
         
sentiment = {"User": target_user,"Compound": np.mean(compound_list),"Tweet Count": len(compound_list)}
CNN_compound=np.mean(compound_list)    
    
for x in range(len(tweet_times)):
    tweet_datetime = datetime.strptime(tweet_times[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects.append(tweet_datetime)
    if x % 20 == 0:
        print(tweet_times[x])
        print(tweet_datetime)
            
for x in range(len(tweet_time_objects)-1):
    hrs_apart = ((tweet_time_objects[x] - tweet_time_objects[x+1]).seconds) / 3600
    time_in_between.append(hrs_apart)

plt.scatter(range(len(time_in_between)+1), compound_list, marker="o",linewidth=0.25, alpha=0.8, color="yellow",edgecolor='k')
plt.xlim([0, len(time_in_between)])
plt.ylabel("Sentiment")
plt.xlabel("Tweets Ago")
plt.title("Tweet Sentiment Analysis")
# Out:
# Wed Sep 26 20:04:25 +0000 2018
# Wed Sep 26 20:04:18 +0000 2018
# Wed Sep 26 20:04:13 +0000 2018
# Wed Sep 26 20:04:05 +0000 2018
# Wed Sep 26 20:04:00 +0000 2018
# Wed Sep 26 20:04:31 +0000 2018
# 2018-09-26 20:04:31+00:00
# Wed Sep 26 20:04:25 +0000 2018
# 2018-09-26 20:04:25+00:00
# Wed Sep 26 20:04:18 +0000 2018
# 2018-09-26 20:04:18+00:00
# Wed Sep 26 20:04:12 +0000 2018
# 2018-09-26 20:04:12+00:00
# Wed Sep 26 20:04:05 +0000 2018
# 2018-09-26 20:04:05+00:00
# Text(0.5,1,'Tweet Sentiment Analysis')

# %%
# Target User
target_user = "CBS"

compound_list = []
tweet_times = []
tweet_time_objects = []
time_in_between = []
counter=0

public_tweets = api.search(target_user, count=100, result_type="recent")
        
for tweet in public_tweets["statuses"]:
        
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    compound_list.append(compound)
        
    tweet_times.append(tweet["created_at"])
        
    counter += 1
    if counter % 20 == 0:
        print(tweet["created_at"])
         
sentiment = {"User": target_user,"Compound": np.mean(compound_list),"Tweet Count": len(compound_list)}
CBS_compound=np.mean(compound_list)    
    
for x in range(len(tweet_times)):
    tweet_datetime = datetime.strptime(tweet_times[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects.append(tweet_datetime)
    if x % 20 == 0:
        print(tweet_times[x])
        print(tweet_datetime)
            
for x in range(len(tweet_time_objects)-1):
    hrs_apart = ((tweet_time_objects[x] - tweet_time_objects[x+1]).seconds) / 3600
    time_in_between.append(hrs_apart)

plt.scatter(range(len(time_in_between)+1), compound_list, marker="o",linewidth=0.25, alpha=0.8, color="green",edgecolor='k')
plt.xlim([0, len(time_in_between)])
plt.ylabel("Sentiment")
plt.xlabel("Tweets Ago")
plt.title("Tweet Sentiment Analysis")
# Out:
# Wed Sep 26 20:03:14 +0000 2018
# Wed Sep 26 20:02:14 +0000 2018
# Wed Sep 26 20:01:21 +0000 2018
# Wed Sep 26 20:00:24 +0000 2018
# Wed Sep 26 19:59:53 +0000 2018
# Wed Sep 26 20:04:22 +0000 2018
# 2018-09-26 20:04:22+00:00
# Wed Sep 26 20:03:13 +0000 2018
# 2018-09-26 20:03:13+00:00
# Wed Sep 26 20:02:13 +0000 2018
# 2018-09-26 20:02:13+00:00
# Wed Sep 26 20:01:21 +0000 2018
# 2018-09-26 20:01:21+00:00
# Wed Sep 26 20:00:23 +0000 2018
# 2018-09-26 20:00:23+00:00
# Text(0.5,1,'Tweet Sentiment Analysis')

# %%
# Target User
target_user = "Fox"

compound_list = []
tweet_times = []
tweet_time_objects = []
time_in_between = []
counter=0

public_tweets = api.search(target_user, count=100, result_type="recent")
        
for tweet in public_tweets["statuses"]:
        
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    compound_list.append(compound)
        
    tweet_times.append(tweet["created_at"])
        
    counter += 1
    if counter % 20 == 0:
        print(tweet["created_at"])
         
sentiment = {"User": target_user,"Compound": np.mean(compound_list),"Tweet Count": len(compound_list)}
Fox_compound=np.mean(compound_list)

for x in range(len(tweet_times)):
    tweet_datetime = datetime.strptime(tweet_times[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects.append(tweet_datetime)
    if x % 20 == 0:
        print(tweet_times[x])
        print(tweet_datetime)
            
for x in range(len(tweet_time_objects)-1):
    hrs_apart = ((tweet_time_objects[x] - tweet_time_objects[x+1]).seconds) / 3600
    time_in_between.append(hrs_apart)

plt.scatter(range(len(time_in_between)+1), compound_list, marker="o",linewidth=0.25, alpha=0.8, color="coral",edgecolor='k')
plt.xlim([0, len(time_in_between)])
plt.ylabel("Sentiment")
plt.xlabel("Tweets Ago")
plt.title("Tweet Sentiment Analysis")
# Out:
# Wed Sep 26 20:04:23 +0000 2018
# Wed Sep 26 20:04:18 +0000 2018
# Wed Sep 26 20:04:09 +0000 2018
# Wed Sep 26 20:04:02 +0000 2018
# Wed Sep 26 20:03:55 +0000 2018
# Wed Sep 26 20:04:31 +0000 2018
# 2018-09-26 20:04:31+00:00
# Wed Sep 26 20:04:23 +0000 2018
# 2018-09-26 20:04:23+00:00
# Wed Sep 26 20:04:18 +0000 2018
# 2018-09-26 20:04:18+00:00
# Wed Sep 26 20:04:09 +0000 2018
# 2018-09-26 20:04:09+00:00
# Wed Sep 26 20:04:02 +0000 2018
# 2018-09-26 20:04:02+00:00
# Text(0.5,1,'Tweet Sentiment Analysis')

# %%
avg=[BBC_compound,NYT_compound,CNN_compound,CBS_compound,Fox_compound]

# %%
print(avg)
# Out:
# [-0.029499999999999988, 0.015449999999999998, -0.05616000000000001, 0.16905699999999999, 0.06007100000000001]
