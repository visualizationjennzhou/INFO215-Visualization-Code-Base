# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(10,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x1178737b8>,
#   <matplotlib.axis.XTick at 0x117873128>,
#   <matplotlib.axis.XTick at 0x114d35da0>,
#   <matplotlib.axis.XTick at 0x117917898>,
#   <matplotlib.axis.XTick at 0x117917d68>,
#   <matplotlib.axis.XTick at 0x117926278>,
#   <matplotlib.axis.XTick at 0x117926780>,
#   <matplotlib.axis.XTick at 0x117926c88>,
#   <matplotlib.axis.XTick at 0x11792f1d0>,
#   <matplotlib.axis.XTick at 0x11792f6d8>,
#   <matplotlib.axis.XTick at 0x11792fbe0>,
#   <matplotlib.axis.XTick at 0x117935160>,
#   <matplotlib.axis.XTick at 0x11792ff60>,
#   <matplotlib.axis.XTick at 0x117926588>,
#   <matplotlib.axis.XTick at 0x1179351d0>,
#   <matplotlib.axis.XTick at 0x117935a58>,
#   <matplotlib.axis.XTick at 0x117935f60>,
#   <matplotlib.axis.XTick at 0x11793d4a8>,
#   <matplotlib.axis.XTick at 0x11793d9b0>,
#   <matplotlib.axis.XTick at 0x11793deb8>,
#   <matplotlib.axis.XTick at 0x117947400>,
#   <matplotlib.axis.XTick at 0x11793d7b8>,
#   <matplotlib.axis.XTick at 0x117935b38>,
#   <matplotlib.axis.XTick at 0x1179477b8>,
#   <matplotlib.axis.XTick at 0x117947d30>,
#   <matplotlib.axis.XTick at 0x117950278>,
#   <matplotlib.axis.XTick at 0x117950780>,
#   <matplotlib.axis.XTick at 0x117950c88>,
#   <matplotlib.axis.XTick at 0x1179571d0>,
#   <matplotlib.axis.XTick at 0x1179576d8>,
#   <matplotlib.axis.XTick at 0x117957be0>,
#   <matplotlib.axis.XTick at 0x117950358>,
#   <matplotlib.axis.XTick at 0x117947828>,
#   <matplotlib.axis.XTick at 0x1179576a0>,
#   <matplotlib.axis.XTick at 0x117961198>,
#   <matplotlib.axis.XTick at 0x117961668>,
#   <matplotlib.axis.XTick at 0x117961b70>,
#   <matplotlib.axis.XTick at 0x117969128>,
#   <matplotlib.axis.XTick at 0x1179695c0>,
#   <matplotlib.axis.XTick at 0x117969ac8>,
#   <matplotlib.axis.XTick at 0x117961e80>,
#   <matplotlib.axis.XTick at 0x1179478d0>,
#   <matplotlib.axis.XTick at 0x117969518>,
#   <matplotlib.axis.XTick at 0x117971358>,
#   <matplotlib.axis.XTick at 0x117971860>,
#   <matplotlib.axis.XTick at 0x117971d68>,
#   <matplotlib.axis.XTick at 0x1179792b0>,
#   <matplotlib.axis.XTick at 0x1179797b8>,
#   <matplotlib.axis.XTick at 0x117979cc0>,
#   <matplotlib.axis.XTick at 0x117979898>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0,0.5,'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout(pad=0.8)
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(10,3))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
